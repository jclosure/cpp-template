# %%
# %pip install scipy matplotlib pandas
# %pip install -r "./requirements.txt"

# %%
import pandas as pd

# %%
data_path = "./outputs/main_benchmark.csv"
script_path = './plot.py'

# %%
df = pd.read_csv(data_path)
df
# Out:
#                        name  iterations   real_time    cpu_time time_unit  \
# 0      BM_SomeFunction/1024     7309178     96.2528     96.2409        ns
# 1      BM_SomeFunction/2048     4518636    157.0050    156.9950        ns
# 2      BM_SomeFunction/4096     2777216    261.6500    261.6190        ns
# 3      BM_SomeFunction/8192     1594406    443.4250    443.3360        ns
# 4     BM_SomeFunction/16384      856929    804.8080    804.8040        ns
# 5     BM_SomeFunction/32768      447270   1577.5300   1574.4500        ns
# 6     BM_SomeFunction/65536      223464   3131.7300   3131.6000        ns
# 7    BM_SomeFunction/131072      106626   6514.8700   6514.8000        ns
# 8    BM_SomeFunction/262144       56717  12276.0000  12275.2000        ns
# 9    BM_SomeFunction/524288       29148  24561.8000  24556.9000        ns
# 10  BM_SomeFunction/1048576       14348  48126.6000  48024.3000        ns
#
#     bytes_per_second  items_per_second  label  error_occurred  error_message
# ...

# %%
import subprocess
from IPython.display import Image
from IPython.display import display

# run the external script against our generated data
subprocess.call([script_path, './outputs/main_benchmark.csv'])

# display the plot images it made
display(
    Image(filename='./outputs/bs_vs_bs_par_1e8.png'),
    Image(filename='./outputs/bs_vs_bs_par_10k.png')
)
# Out:
#           n             name   real_time
# 0      1024  BM_SomeFunction     96.2528
# 1      2048  BM_SomeFunction    157.0050
# 2      4096  BM_SomeFunction    261.6500
# 3      8192  BM_SomeFunction    443.4250
# 4     16384  BM_SomeFunction    804.8080
# 5     32768  BM_SomeFunction   1577.5300
# 6     65536  BM_SomeFunction   3131.7300
# 7    131072  BM_SomeFunction   6514.8700
# 8    262144  BM_SomeFunction  12276.0000
# 9    524288  BM_SomeFunction  24561.8000
# 10  1048576  BM_SomeFunction  48126.6000
#           n  real_time_BM_SomeFunction
# 0      1024                    96.2528
# 1      2048                   157.0050
# 2      4096                   261.6500
# 3      8192                   443.4250
# 4     16384                   804.8080
# 5     32768                  1577.5300
# 6     65536                  3131.7300
# 7    131072                  6514.8700
# 8    262144                 12276.0000
# 9    524288                 24561.8000
# ...
